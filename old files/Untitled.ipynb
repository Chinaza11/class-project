# %%
import sqlite3
from matplotlib import pyplot as plt
import plotly.express as px
import pandas as pd
from flask import Flask, request, render_template, redirect, url_for
from datetime import *
import pytz
import plotly.express as px
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
import io
import base64
import sqlite3
import os
from os.path import join, dirname, realpath
from sklearn import *
import pickle
import joblib
from numpy import *

# %%
filename = 'finalized_model.sav'
loaded_model = joblib.load(filename)
result = loaded_model.predict([[2,2,4,120,7,3.4,24.137931,0,0,0,0,0,1], [2,2,4,120,7,3.4,24.137931,0,0,0,0,0,1]])
print(result)
# Out:
# ['high' 'high']

# %%
r = pd.DataFrame(result,columns=['Predict'])
r = r.to_html()

# %%
con = sqlite3.connect('pred.db')
df_p = pd.read_sql('select * from treatments',con)
df_p
# Out:
#    treatments_id  treatments_name  year  replicate  \
# 0              1  Untreated check  2019          1
# 1              2  Untreated check  2019          1
# 2              3  Untreated check  2019          1
# 3              4  Untreated check  2019          1
#
#    root_knot_nematode_planting  root_knot_nematode_midseason  \
# 0                           20                            10
# 1                           20                            10
# 2                           20                            10
# 3                           20                            10
#
#    root_knot_nematode_end_of_season  weed  vigor_rating  gall_rating  \
# 0                               320    10            10            5
# 1                               320    10            10            5
# 2                               150    10            10            5
# 3                               320    10            10            5
#
#    fruit_yield  southern_blight   latitude  longitude  dominus  paladin  \
# 0           10               50  31.502951 -83.545263        0        0
# 1           10               50  31.502951 -83.545263        0        0
# 2           10               50  31.502951 -83.545263        1        0
# 3           10               50  31.502951 -83.545263        1        0
#
#    pic_60  resistant_variety  telone  untreated_check
# 0       1                  0       0                0
# 1       0                  0       1                0
# 2       0                  0       0                0
# 3       0                  0       0                0

# %%
df_p = df_p [['root_knot_nematode_planting', 'root_knot_nematode_midseason', 'root_knot_nematode_end_of_season', 'weed', 'vigor_rating', 'gall_rating', 'fruit_yield', 'southern_blight', 'dominus', 'paladin', 'pic_60', 'resistant_variety', 'telone', 'untreated_check']]
df_p = df_p.set_index('root_knot_nematode_planting')
df_p
# Out:
#                              root_knot_nematode_midseason  \
# root_knot_nematode_planting
# 20                                                     10
# 20                                                     10
# 20                                                     10
# 20                                                     10
#
#                              root_knot_nematode_end_of_season  weed  \
# root_knot_nematode_planting
# 20                                                        320    10
# 20                                                        320    10
# 20                                                        150    10
# 20                                                        320    10
#
#                              vigor_rating  gall_rating  fruit_yield  \
# root_knot_nematode_planting
# 20                                     10            5           10
# 20                                     10            5           10
# 20                                     10            5           10
# 20                                     10            5           10
#
#                              southern_blight  dominus  paladin  pic_60  \
# root_knot_nematode_planting
# 20                                        50        0        0       1
# 20                                        50        0        0       0
# 20                                        50        1        0       0
# 20                                        50        1        0       0
#
#                              resistant_variety  telone  untreated_check
# root_knot_nematode_planting
# 20                                           0       0                0
# 20                                           0       1                0
# 20                                           0       0                0
# 20                                           0       0                0

# %%
predictions = loaded_model.predict(df_p)
predictions
# Out:
# array(['low', 'low', 'low', 'low'], dtype=object)

# %%
results =  pd.DataFrame(predictions,columns=['Predict'])
results
# Out:
#   Predict
# 0     low
# 1     low
# 2     low
# 3     low
